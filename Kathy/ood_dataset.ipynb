# %%
import pandas as pd 

df = pd.read_csv('../wikidata_global_companies_info.csv') 
df.head()
# Out:
#    Unnamed: 0                            wikidata_uri   company name  \
# 0           0  http://www.wikidata.org/entity/Q279260   Hotel Sacher
# 1           1  http://www.wikidata.org/entity/Q193326  Goldman Sachs
# 2           2  http://www.wikidata.org/entity/Q205012       Sberbank
# 3           3  http://www.wikidata.org/entity/Q180855       Heineken
# 4           4   http://www.wikidata.org/entity/Q66048  Deutsche Bank
#
#                                          description  \
# 0          building in Innere Stadt, Vienna, Austria
# 1                           American investment bank
# 2     Russian banking and financial services company
# 3                                 Dutch beer company
# 4  German global banking and financial services c...
#
#                     country  \
# 0                   Austria
# 1  United States of America
# 2                    Russia
# 3               Netherlands
# 4                   Germany
#
# ...

# %%
df2 = pd.read_csv('../wikidata_global_companies_info.csv') 
df2.head()
# Out:
#    Unnamed: 0                            wikidata_uri   company name  \
# 0           0  http://www.wikidata.org/entity/Q279260   Hotel Sacher
# 1           1  http://www.wikidata.org/entity/Q193326  Goldman Sachs
# 2           2  http://www.wikidata.org/entity/Q205012       Sberbank
# 3           3  http://www.wikidata.org/entity/Q180855       Heineken
# 4           4   http://www.wikidata.org/entity/Q66048  Deutsche Bank
#
#                                          description  \
# 0          building in Innere Stadt, Vienna, Austria
# 1                           American investment bank
# 2     Russian banking and financial services company
# 3                                 Dutch beer company
# 4  German global banking and financial services c...
#
#                     country  \
# 0                   Austria
# 1  United States of America
# 2                    Russia
# 3               Netherlands
# 4                   Germany
#
# ...
